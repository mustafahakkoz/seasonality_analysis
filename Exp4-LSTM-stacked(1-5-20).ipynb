# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import tensorflow as tf
import random
# set experiment consistency
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# Load data from the text file
with open('./data/IBM.txt', 'r') as file:
    lines = file.readlines()
    data = []
    dates = []

    for line in lines[1:]:
        parts = line.strip().split(',')
        date = parts[0]
        if '1980-12-12' <= date <= '2022-07-22':
            dates.append(date)
            data.append(float(parts[4]))  # 'Close' column

# Create a DataFrame from the loaded data
df = pd.DataFrame({'Date': pd.to_datetime(dates), 'Value': data})

# Set the 'Date' column as the index
df.set_index('Date', inplace=True)

# Extract the values from the DataFrame
signal = df['Value'].values
signal = signal.reshape(-1, 1)

# Define the training and testing data
train_size = int(len(signal) * 0.8)
train_data = signal[:train_size, :]
test_data = signal[train_size:, :]

# normalization
scaler = MinMaxScaler()
scaler.fit(train_data)
train_data = scaler.transform(train_data)
test_data = scaler.transform(test_data)

def create_groups(dataset, window_size_1, window_size_2, window_size_3, timeslice, step):
    X_data, y_data = [], []
    index = 0
    while index + (timeslice * window_size_3) < len(dataset):
        i = 0
        t1, t2, t3 = [], [], []
        l1, l2, l3 = [], [], []
        while i < timeslice* window_size_1:
            current_slice = dataset[index + i:index + i + window_size_1, 0]
            if not np.isnan(current_slice).all():
                t1.append(np.mean(current_slice))
                
            i = i + window_size_1
        l1.append(dataset[index +  timeslice*window_size_1])
        i = 0   
        while i < timeslice* window_size_2:
            current_slice = dataset[index + i:index + i + window_size_2, 0]
            if not np.isnan(current_slice).all():
                t2.append(np.mean(current_slice))
                
            i = i + window_size_2
        l2.append(dataset[index + timeslice*window_size_2])
        i = 0   
        while i < timeslice* window_size_3:
            current_slice = dataset[index + i:index + i + window_size_3, 0]
            if not np.isnan(current_slice).all():
                t3.append(np.mean(current_slice))
            
            i = i + window_size_3
        l3.append(dataset[index + timeslice*window_size_3])
        X_data.append(np.concatenate([t1, t2, t3]))
        y_data.append(np.concatenate([l3]))
        index = index +step

    return np.array(X_data), np.array(y_data)

window_size_1 = 1
window_size_2 = 5
window_size_3 = 20
timeslice = 4
step = 1
X_train, y_train = create_groups(train_data, window_size_1, window_size_2, window_size_3, timeslice, step)
X_test, y_test = create_groups(test_data, window_size_1, window_size_2, window_size_3, timeslice, step)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
y_train[0]
# Out:
# array([[0.02310873]])

# %%
# Define the LSTM model architecture
model = Sequential()
model.add(LSTM(units=16, return_sequences=True, input_shape=(X_train.shape[1], 1)))
# model.add(Dropout(0.2))
model.add(LSTM(units=32, return_sequences=True))
# model.add(Dropout(0.2))
model.add(LSTM(units=16, return_sequences=False))
# model.add(Dropout(0.2))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Plot the training loss and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 260/260 [==============================] - 4s 7ms/step - loss: 0.0080 - val_loss: 0.0048
# Epoch 2/100
# 260/260 [==============================] - 2s 6ms/step - loss: 0.0024 - val_loss: 0.0045
# Epoch 3/100
# 260/260 [==============================] - 2s 6ms/step - loss: 0.0022 - val_loss: 0.0062
# Epoch 4/100
# 260/260 [==============================] - 1s 6ms/step - loss: 0.0021 - val_loss: 0.0050
# Epoch 5/100
# 260/260 [==============================] - 1s 6ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 6/100
# 260/260 [==============================] - 1s 6ms/step - loss: 0.0016 - val_loss: 0.0034
# Epoch 7/100
# 260/260 [==============================] - 1s 6ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 8/100
# 260/260 [==============================] - 1s 6ms/step - loss: 8.9528e-04 - val_loss: 0.0018
# Epoch 9/100
# 260/260 [==============================] - 2s 6ms/step - loss: 7.5174e-04 - val_loss: 0.0014
# Epoch 10/100
# 260/260 [==============================] - 1s 6ms/step - loss: 6.2989e-04 - val_loss: 0.0011
# Epoch 11/100
# 260/260 [==============================] - 1s 6ms/step - loss: 5.1095e-04 - val_loss: 8.3902e-04
# Epoch 12/100
# 260/260 [==============================] - 1s 6ms/step - loss: 4.3144e-04 - val_loss: 7.7181e-04
# Epoch 13/100
# 260/260 [==============================] - 1s 6ms/step - loss: 4.1453e-04 - val_loss: 0.0010
# Epoch 14/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.7282e-04 - val_loss: 7.3568e-04
# Epoch 15/100
# 260/260 [==============================] - 2s 6ms/step - loss: 3.5158e-04 - val_loss: 7.5345e-04
# Epoch 16/100
# 260/260 [==============================] - 2s 6ms/step - loss: 3.4802e-04 - val_loss: 0.0010
# Epoch 17/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.4943e-04 - val_loss: 7.0908e-04
# Epoch 18/100
# 260/260 [==============================] - 2s 6ms/step - loss: 3.4940e-04 - val_loss: 6.8159e-04
# Epoch 19/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.1980e-04 - val_loss: 7.9550e-04
# Epoch 20/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.1869e-04 - val_loss: 7.0198e-04
# Epoch 21/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.2345e-04 - val_loss: 7.4597e-04
# Epoch 22/100
# 260/260 [==============================] - 2s 6ms/step - loss: 3.1120e-04 - val_loss: 7.4441e-04
# Epoch 23/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.2082e-04 - val_loss: 7.8978e-04
# Epoch 24/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.2018e-04 - val_loss: 7.7250e-04
# Epoch 25/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.3495e-04 - val_loss: 7.4802e-04
# Epoch 26/100
# 260/260 [==============================] - 2s 6ms/step - loss: 3.1811e-04 - val_loss: 9.1256e-04
# Epoch 27/100
# 260/260 [==============================] - 2s 6ms/step - loss: 3.1625e-04 - val_loss: 6.8375e-04
# Epoch 28/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.0894e-04 - val_loss: 7.3679e-04
# Epoch 29/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.0363e-04 - val_loss: 7.4550e-04
# Epoch 30/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.2004e-04 - val_loss: 7.6865e-04
# Epoch 31/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.1901e-04 - val_loss: 7.3735e-04
# Epoch 32/100
# 260/260 [==============================] - 2s 6ms/step - loss: 3.0436e-04 - val_loss: 7.4378e-04
# Epoch 33/100
# 260/260 [==============================] - 2s 6ms/step - loss: 3.1253e-04 - val_loss: 7.5231e-04
# Epoch 34/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.1768e-04 - val_loss: 6.8685e-04
# Epoch 35/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.0128e-04 - val_loss: 7.8722e-04
# Epoch 36/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.9526e-04 - val_loss: 7.2735e-04
# Epoch 37/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.1743e-04 - val_loss: 7.0374e-04
# Epoch 38/100
# 260/260 [==============================] - 2s 6ms/step - loss: 3.1123e-04 - val_loss: 8.1409e-04
# Epoch 39/100
# 260/260 [==============================] - 2s 6ms/step - loss: 3.0685e-04 - val_loss: 0.0011
# Epoch 40/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.9944e-04 - val_loss: 7.0878e-04
# Epoch 41/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.0007e-04 - val_loss: 6.9042e-04
# Epoch 42/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.0248e-04 - val_loss: 0.0011
# Epoch 43/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.9426e-04 - val_loss: 7.4645e-04
# Epoch 44/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.0167e-04 - val_loss: 7.8171e-04
# Epoch 45/100
# 260/260 [==============================] - 2s 6ms/step - loss: 3.0643e-04 - val_loss: 6.7811e-04
# Epoch 46/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.9438e-04 - val_loss: 6.9725e-04
# Epoch 47/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.9546e-04 - val_loss: 7.1359e-04
# Epoch 48/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.9603e-04 - val_loss: 8.3261e-04
# Epoch 49/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.0195e-04 - val_loss: 9.5432e-04
# Epoch 50/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.9053e-04 - val_loss: 7.1163e-04
# Epoch 51/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.9644e-04 - val_loss: 7.4628e-04
# Epoch 52/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.1046e-04 - val_loss: 9.4194e-04
# Epoch 53/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.8376e-04 - val_loss: 8.0326e-04
# Epoch 54/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.1223e-04 - val_loss: 6.9542e-04
# Epoch 55/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.8899e-04 - val_loss: 0.0010
# Epoch 56/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.8961e-04 - val_loss: 7.4785e-04
# Epoch 57/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.9163e-04 - val_loss: 8.9162e-04
# Epoch 58/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.9872e-04 - val_loss: 7.5758e-04
# Epoch 59/100
# 260/260 [==============================] - 1s 6ms/step - loss: 3.0129e-04 - val_loss: 7.4751e-04
# Epoch 60/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.8638e-04 - val_loss: 8.3083e-04
# Epoch 61/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.9348e-04 - val_loss: 7.1279e-04
# Epoch 62/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.9330e-04 - val_loss: 7.5901e-04
# Epoch 63/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.8487e-04 - val_loss: 8.3600e-04
# Epoch 64/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.9372e-04 - val_loss: 7.6248e-04
# Epoch 65/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.9617e-04 - val_loss: 7.8766e-04
# Epoch 66/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.8541e-04 - val_loss: 8.2178e-04
# Epoch 67/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.9671e-04 - val_loss: 7.7984e-04
# Epoch 68/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.8388e-04 - val_loss: 8.1338e-04
# Epoch 69/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.8667e-04 - val_loss: 7.6674e-04
# Epoch 70/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.9603e-04 - val_loss: 9.7835e-04
# Epoch 71/100
# 260/260 [==============================] - 2s 6ms/step - loss: 3.0167e-04 - val_loss: 7.8704e-04
# Epoch 72/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7651e-04 - val_loss: 7.6395e-04
# Epoch 73/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.8093e-04 - val_loss: 7.1647e-04
# Epoch 74/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.9394e-04 - val_loss: 8.3611e-04
# Epoch 75/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.8127e-04 - val_loss: 7.5077e-04
# Epoch 76/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.8672e-04 - val_loss: 8.9353e-04
# Epoch 77/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7440e-04 - val_loss: 7.7404e-04
# Epoch 78/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.8172e-04 - val_loss: 8.7539e-04
# Epoch 79/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.7910e-04 - val_loss: 7.4636e-04
# Epoch 80/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.8048e-04 - val_loss: 8.3287e-04
# Epoch 81/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.8206e-04 - val_loss: 0.0012
# Epoch 82/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.8071e-04 - val_loss: 8.0478e-04
# Epoch 83/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.8083e-04 - val_loss: 8.5602e-04
# Epoch 84/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.7942e-04 - val_loss: 8.0574e-04
# Epoch 85/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7875e-04 - val_loss: 8.6985e-04
# Epoch 86/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7614e-04 - val_loss: 0.0010
# Epoch 87/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7654e-04 - val_loss: 8.4679e-04
# Epoch 88/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7251e-04 - val_loss: 8.3943e-04
# Epoch 89/100
# 260/260 [==============================] - 1s 6ms/step - loss: 2.7885e-04 - val_loss: 8.0071e-04
# Epoch 90/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7481e-04 - val_loss: 9.2172e-04
# Epoch 91/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7512e-04 - val_loss: 8.8905e-04
# Epoch 92/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.8037e-04 - val_loss: 9.5201e-04
# Epoch 93/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7439e-04 - val_loss: 0.0010
# Epoch 94/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7718e-04 - val_loss: 9.0263e-04
# Epoch 95/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7112e-04 - val_loss: 8.6330e-04
# Epoch 96/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.8031e-04 - val_loss: 0.0010
# Epoch 97/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.6889e-04 - val_loss: 8.2924e-04
# Epoch 98/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7244e-04 - val_loss: 0.0011
# Epoch 99/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.6794e-04 - val_loss: 9.1565e-04
# Epoch 100/100
# 260/260 [==============================] - 2s 6ms/step - loss: 2.7088e-04 - val_loss: 9.7904e-04

# %%
# Make predictions
y_pred = model.predict(X_test)

y_test = y_test.reshape((y_test.shape[0], y_test.shape[1]))
y_pred = scaler.inverse_transform(y_pred)
y_test = scaler.inverse_transform(y_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
msle = mean_squared_log_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Assuming y_pred and y_test are NumPy arrays
# Note: For MAPE, make sure y_test does not contain zeros to avoid division by zero.

# RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# MAPE
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100


print('RMSE:', rmse)
print('MAPE:', mape)


print('MSE: ', mse)
print('MSLE: ', msle)
print('MAE: ', mae)
print('R-squared: ', r2)

# Plot the predictions vs the real data
plt.plot(y_test, color='blue', label='Actual Price')
plt.plot(y_pred, color='red', label='Predicted Price')
plt.title('IBM Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('IBM Stock Price')
plt.legend()
plt.show()
# Out:
# 64/64 [==============================] - 1s 1ms/step
# RMSE: 6.148750719875557
# MAPE: 3.374521495186912
# MSE:  37.80713541517019
# MSLE:  0.0021699665947833365
# MAE:  4.5070086574754225
# R-squared:  0.8586350004953403

# %% [markdown]
# # 1
# RMSE: 3.4254854508410113
# MAPE: 1.8144602678363666
# MSE:  11.733950573923448
# MSLE:  0.0006569501219651215
# MAE:  2.4491094395626716
# R-squared:  0.9631499914253284
#
# # 1-3
#
# RMSE: 6.078880969983048
# MAPE: 3.316567922817762
# MSE:  36.95279384722205
# MSLE:  0.002067308836169198
# MAE:  4.445746821684231
# R-squared:  0.8816022738103634
#
# # 1-3-9
# RMSE: 9.681496370442565
# MAPE: 5.433762503375542
# MSE:  93.73137197089255
# MSLE:  0.005184730334292754
# MAE:  7.309876317143523
# R-squared:  0.6795390158852281
#
# # 1-5-20
# RMSE: 12.73980415817289
# MAPE: 7.46507220205909
# MSE:  162.30260998859924
# MSLE:  0.008368224922447263
# MAE:  10.103675051213184
# R-squared:  0.3931328536613483
