# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import tensorflow as tf
import random
# set experiment consistency
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# Load data from the text file
with open('./data/IBM.txt', 'r') as file:
    lines = file.readlines()
    data = []
    dates = []

    for line in lines[1:]:
        parts = line.strip().split(',')
        date = parts[0]
        if '1980-12-12' <= date <= '2022-07-22':
            dates.append(date)
            data.append(float(parts[4]))  # 'Close' column

# Create a DataFrame from the loaded data
df = pd.DataFrame({'Date': pd.to_datetime(dates), 'Value': data})

# Set the 'Date' column as the index
df.set_index('Date', inplace=True)

# Extract the values from the DataFrame
signal = df['Value'].values
signal = signal.reshape(-1, 1)

# Define the training and testing data
train_size = int(len(signal) * 0.8)
train_data = signal[:train_size, :]
test_data = signal[train_size:, :]

# normalization
scaler = MinMaxScaler()
scaler.fit(train_data)
train_data = scaler.transform(train_data)
test_data = scaler.transform(test_data)

def create_groups(dataset, window_size_2, window_size_3, timeslice, step):
    X_data, y_data = [], []
    index = 0
    while index + (timeslice * window_size_3) < len(dataset):
        i = 0
        t2, t3 = [], []

        # Populate t3
        while i < timeslice * window_size_3:
            current_slice = dataset[index + i:index + i + window_size_3, 0]
            if not np.isnan(current_slice).all():
                t3.append(np.mean(current_slice))
            i += window_size_3

        # Populate t2
        j = timeslice * window_size_3- timeslice * window_size_2
        while j < i:
            current_slice = dataset[index + j:index + j + window_size_2, 0]
            if not np.isnan(current_slice).all():
                t2.append(np.mean(current_slice))
            j += window_size_2

        # Populate t1
        
        t3=np.flip(t3)
        t2=np.flip(t2)
       
        X_data.append(np.concatenate([t2, t3]))
        y_data.append(dataset[index + timeslice * window_size_3])
        index += step

    return np.array(X_data), np.array(y_data)

window_size_1 = 1
window_size_2 = 3
window_size_3 = 9
timeslice = 4
step = 1
X_train, y_train = create_groups(train_data, window_size_1, window_size_2, timeslice, step)
X_test, y_test = create_groups(test_data, window_size_1, window_size_2, timeslice, step)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
y_train[0]
# Out:
# array([0.03268669])

# %%
# Define the LSTM model architecture
model = Sequential()
model.add(LSTM(units=16, return_sequences=True, input_shape=(X_train.shape[1], 1)))
# model.add(Dropout(0.2))
model.add(LSTM(units=32, return_sequences=True))
# model.add(Dropout(0.2))
model.add(LSTM(units=16, return_sequences=False))
# model.add(Dropout(0.2))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Plot the training loss and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 262/262 [==============================] - 3s 6ms/step - loss: 0.0079 - val_loss: 3.4036e-04
# Epoch 2/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0839e-04 - val_loss: 2.9163e-04
# Epoch 3/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1170e-04 - val_loss: 2.2854e-04
# Epoch 4/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1027e-04 - val_loss: 2.3880e-04
# Epoch 5/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.2071e-04 - val_loss: 2.6287e-04
# Epoch 6/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1954e-04 - val_loss: 2.1778e-04
# Epoch 7/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1085e-04 - val_loss: 2.4000e-04
# Epoch 8/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1999e-04 - val_loss: 2.0142e-04
# Epoch 9/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1749e-04 - val_loss: 2.5336e-04
# Epoch 10/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0760e-04 - val_loss: 4.7608e-04
# Epoch 11/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1620e-04 - val_loss: 2.0158e-04
# Epoch 12/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1399e-04 - val_loss: 3.5589e-04
# Epoch 13/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1497e-04 - val_loss: 1.9492e-04
# Epoch 14/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0495e-04 - val_loss: 2.2943e-04
# Epoch 15/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0781e-04 - val_loss: 1.9387e-04
# Epoch 16/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.2349e-04 - val_loss: 2.0407e-04
# Epoch 17/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0769e-04 - val_loss: 1.9118e-04
# Epoch 18/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1340e-04 - val_loss: 5.7325e-04
# Epoch 19/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0827e-04 - val_loss: 1.8967e-04
# Epoch 20/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0573e-04 - val_loss: 2.5800e-04
# Epoch 21/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1806e-04 - val_loss: 1.8874e-04
# Epoch 22/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0403e-04 - val_loss: 1.8855e-04
# Epoch 23/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0943e-04 - val_loss: 3.1978e-04
# Epoch 24/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0530e-04 - val_loss: 2.6719e-04
# Epoch 25/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0660e-04 - val_loss: 1.8664e-04
# Epoch 26/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0477e-04 - val_loss: 1.9793e-04
# Epoch 27/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.2780e-04 - val_loss: 4.0217e-04
# Epoch 28/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1742e-04 - val_loss: 1.9756e-04
# Epoch 29/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0290e-04 - val_loss: 2.4758e-04
# Epoch 30/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0621e-04 - val_loss: 2.5210e-04
# Epoch 31/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0612e-04 - val_loss: 2.0572e-04
# Epoch 32/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0463e-04 - val_loss: 2.1022e-04
# Epoch 33/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0360e-04 - val_loss: 2.1217e-04
# Epoch 34/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.1002e-04 - val_loss: 2.2198e-04
# Epoch 35/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0820e-04 - val_loss: 1.8300e-04
# Epoch 36/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.7652e-05 - val_loss: 6.2451e-04
# Epoch 37/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0499e-04 - val_loss: 2.3679e-04
# Epoch 38/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0621e-04 - val_loss: 1.9033e-04
# Epoch 39/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.5647e-05 - val_loss: 1.8367e-04
# Epoch 40/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0537e-04 - val_loss: 3.5924e-04
# Epoch 41/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.9313e-05 - val_loss: 1.8533e-04
# Epoch 42/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.5457e-05 - val_loss: 2.0240e-04
# Epoch 43/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0136e-04 - val_loss: 2.1001e-04
# Epoch 44/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.4786e-05 - val_loss: 2.5643e-04
# Epoch 45/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.9452e-05 - val_loss: 3.4312e-04
# Epoch 46/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.2164e-05 - val_loss: 4.3248e-04
# Epoch 47/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0588e-04 - val_loss: 1.9591e-04
# Epoch 48/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.1925e-05 - val_loss: 1.9180e-04
# Epoch 49/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.7879e-05 - val_loss: 1.7964e-04
# Epoch 50/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.2156e-05 - val_loss: 2.8290e-04
# Epoch 51/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0094e-04 - val_loss: 3.6235e-04
# Epoch 52/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.0464e-05 - val_loss: 1.8034e-04
# Epoch 53/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.3510e-05 - val_loss: 2.2229e-04
# Epoch 54/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0259e-04 - val_loss: 1.6682e-04
# Epoch 55/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.6264e-05 - val_loss: 2.7965e-04
# Epoch 56/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.4480e-05 - val_loss: 2.0948e-04
# Epoch 57/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.5456e-05 - val_loss: 2.2945e-04
# Epoch 58/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.4448e-05 - val_loss: 3.0470e-04
# Epoch 59/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0162e-04 - val_loss: 1.7663e-04
# Epoch 60/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.1817e-05 - val_loss: 3.3075e-04
# Epoch 61/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.1581e-05 - val_loss: 1.6288e-04
# Epoch 62/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.9043e-05 - val_loss: 2.9146e-04
# Epoch 63/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.0302e-05 - val_loss: 2.2281e-04
# Epoch 64/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.5967e-05 - val_loss: 1.8832e-04
# Epoch 65/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.2546e-05 - val_loss: 1.6256e-04
# Epoch 66/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.1391e-05 - val_loss: 1.6994e-04
# Epoch 67/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.3718e-05 - val_loss: 1.7349e-04
# Epoch 68/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.4240e-05 - val_loss: 1.6202e-04
# Epoch 69/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.8231e-05 - val_loss: 1.8332e-04
# Epoch 70/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.6436e-05 - val_loss: 2.7339e-04
# Epoch 71/100
# 262/262 [==============================] - 1s 4ms/step - loss: 1.0648e-04 - val_loss: 1.9144e-04
# Epoch 72/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.3854e-05 - val_loss: 1.5668e-04
# Epoch 73/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.2537e-05 - val_loss: 3.0055e-04
# Epoch 74/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.0418e-05 - val_loss: 2.9247e-04
# Epoch 75/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.6750e-05 - val_loss: 3.8896e-04
# Epoch 76/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.8664e-05 - val_loss: 1.7027e-04
# Epoch 77/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.7145e-05 - val_loss: 1.6770e-04
# Epoch 78/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.1885e-05 - val_loss: 2.0766e-04
# Epoch 79/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.0253e-05 - val_loss: 1.7849e-04
# Epoch 80/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.8744e-05 - val_loss: 1.5594e-04
# Epoch 81/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.4929e-05 - val_loss: 1.5191e-04
# Epoch 82/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.3919e-05 - val_loss: 1.5704e-04
# Epoch 83/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.4348e-05 - val_loss: 1.6341e-04
# Epoch 84/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.0742e-05 - val_loss: 1.6085e-04
# Epoch 85/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.5511e-05 - val_loss: 1.5759e-04
# Epoch 86/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.9906e-05 - val_loss: 1.5878e-04
# Epoch 87/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.8250e-05 - val_loss: 1.4777e-04
# Epoch 88/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.2082e-05 - val_loss: 1.6237e-04
# Epoch 89/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.9836e-05 - val_loss: 3.0673e-04
# Epoch 90/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.7600e-05 - val_loss: 1.8840e-04
# Epoch 91/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.6116e-05 - val_loss: 1.5278e-04
# Epoch 92/100
# 262/262 [==============================] - 1s 4ms/step - loss: 7.8833e-05 - val_loss: 1.5393e-04
# Epoch 93/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.3469e-05 - val_loss: 1.5352e-04
# Epoch 94/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.4994e-05 - val_loss: 1.5271e-04
# Epoch 95/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.3674e-05 - val_loss: 3.5774e-04
# Epoch 96/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.2095e-05 - val_loss: 3.5547e-04
# Epoch 97/100
# 262/262 [==============================] - 1s 4ms/step - loss: 9.8286e-05 - val_loss: 1.9040e-04
# Epoch 98/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.8323e-05 - val_loss: 1.7418e-04
# Epoch 99/100
# 262/262 [==============================] - 1s 4ms/step - loss: 8.1555e-05 - val_loss: 1.5083e-04
# Epoch 100/100
# 262/262 [==============================] - 1s 4ms/step - loss: 7.7898e-05 - val_loss: 1.5165e-04

# %%
# Make predictions
y_pred = model.predict(X_test)

y_test = y_test.reshape((y_test.shape[0], y_test.shape[1]))
y_pred = scaler.inverse_transform(y_pred)
y_test = scaler.inverse_transform(y_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
msle = mean_squared_log_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Assuming y_pred and y_test are NumPy arrays
# Note: For MAPE, make sure y_test does not contain zeros to avoid division by zero.

# RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# MAPE
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100


print('RMSE:', rmse)
print('MAPE:', mape)


print('MSE: ', mse)
print('MSLE: ', msle)
print('MAE: ', mae)
print('R-squared: ', r2)

# Plot the predictions vs the real data
plt.plot(y_test, color='blue', label='Actual Price')
plt.plot(y_pred, color='red', label='Predicted Price')
plt.title('IBM Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('IBM Stock Price')
plt.legend()
plt.show()
# Out:
# 66/66 [==============================] - 1s 1ms/step
# RMSE: 2.4199813154489176
# MAPE: 1.2886573141681517
# MSE:  5.8563095671218734
# MSLE:  0.0003309508479626706
# MAE:  1.7537373475572793
# R-squared:  0.981236229675176

# %% [markdown]
# # 1-3
#
# RMSE: 6.078880969983048
# MAPE: 3.316567922817762
# MSE:  36.95279384722205
# MSLE:  0.002067308836169198
# MAE:  4.445746821684231
# R-squared:  0.8816022738103634
#
# # 1-3-9
#
# RMSE: 9.681496370442565
# MAPE: 5.433762503375542
# MSE:  93.73137197089255
# MSLE:  0.005184730334292754
# MAE:  7.309876317143523
# R-squared:  0.6795390158852281
