# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import tensorflow as tf
import random
# set experiment consistency
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# turn gpu on
physical_devices = tf.config.list_physical_devices('GPU')
# Load data from the text file
with open('./data/IBM.txt', 'r') as file:
    lines = file.readlines()
    data = []
    dates = []

    for line in lines[1:]:
        parts = line.strip().split(',')
        date = parts[0]
        if '1980-12-12' <= date <= '2022-07-22':
            dates.append(date)
            data.append(float(parts[4]))  # 'Close' column

# Create a DataFrame from the loaded data
df = pd.DataFrame({'Date': pd.to_datetime(dates), 'Value': data})

# Set the 'Date' column as the index
df.set_index('Date', inplace=True)

# Extract the values from the DataFrame
signal = df['Value'].values
signal = signal.reshape(-1, 1)

# Define the training and testing data
train_size = int(len(signal) * 0.8)
train_data = signal[:train_size, :]
test_data = signal[train_size:, :]

# normalization
scaler = MinMaxScaler()
scaler.fit(train_data)
train_data = scaler.transform(train_data)
test_data = scaler.transform(test_data)

def create_groups(dataset, window_size_1, timeslice, step):
    X_data, y_data = [], []
    index = 0
    while index + (timeslice * window_size_1) < len(dataset):
        i = 0
        t1, t2, t3 = [], [], []
        l1, l2, l3 = [], [], []
        while i < timeslice* window_size_1:
            current_slice = dataset[index + i:index + i + window_size_1, 0]
            if not np.isnan(current_slice).all():
                t1.append(np.mean(current_slice))
                
            i = i + window_size_1
        l1.append(dataset[index +  timeslice*window_size_1])
        # i = 0   
        # while i < timeslice* window_size_2:
        #     current_slice = dataset[index + i:index + i + window_size_2, 0]
        #     if not np.isnan(current_slice).all():
        #         t2.append(np.mean(current_slice))
                
        #     i = i + window_size_2
        # l2.append(dataset[index + timeslice*window_size_2])
        # i = 0   
        # while i < timeslice* window_size_3:
        #     current_slice = dataset[index + i:index + i + window_size_3, 0]
        #     if not np.isnan(current_slice).all():
        #         t3.append(np.mean(current_slice))
            
        #     i = i + window_size_3
        # l3.append(dataset[index + timeslice*window_size_3])
        X_data.append(np.concatenate([t1]))
        y_data.append(np.concatenate([l1]))
        index = index +step

    return np.array(X_data), np.array(y_data)

window_size_1 = 1
window_size_2 = 3
window_size_3 = 9
timeslice = 12
step = 1
X_train, y_train = create_groups(train_data, window_size_1, timeslice, step)
X_test, y_test = create_groups(test_data, window_size_1, timeslice, step)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
y_train[0]
# Out:
# array([[0.03268669]])

# %%
# Define the LSTM model architecture
model = Sequential()
model.add(LSTM(units=16, return_sequences=True, input_shape=(X_train.shape[1], 1)))
# model.add(Dropout(0.2))
model.add(LSTM(units=32, return_sequences=True))
# model.add(Dropout(0.2))
model.add(LSTM(units=16, return_sequences=False))
# model.add(Dropout(0.2))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Plot the training loss and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 262/262 [==============================] - 4s 7ms/step - loss: 0.0064 - val_loss: 8.9339e-04
# Epoch 2/100
# 262/262 [==============================] - 1s 5ms/step - loss: 2.9182e-04 - val_loss: 9.2559e-04
# Epoch 3/100
# 262/262 [==============================] - 1s 5ms/step - loss: 2.9527e-04 - val_loss: 5.9085e-04
# Epoch 4/100
# 262/262 [==============================] - 1s 5ms/step - loss: 2.9370e-04 - val_loss: 6.1109e-04
# Epoch 5/100
# 262/262 [==============================] - 1s 5ms/step - loss: 2.9358e-04 - val_loss: 6.8292e-04
# Epoch 6/100
# 262/262 [==============================] - 1s 5ms/step - loss: 2.7538e-04 - val_loss: 7.5698e-04
# Epoch 7/100
# 262/262 [==============================] - 1s 5ms/step - loss: 2.7298e-04 - val_loss: 5.1120e-04
# Epoch 8/100
# 262/262 [==============================] - 1s 5ms/step - loss: 2.5675e-04 - val_loss: 7.9607e-04
# Epoch 9/100
# 262/262 [==============================] - 1s 6ms/step - loss: 2.4663e-04 - val_loss: 6.9628e-04
# Epoch 10/100
# 262/262 [==============================] - 1s 5ms/step - loss: 2.4011e-04 - val_loss: 9.0677e-04
# Epoch 11/100
# 262/262 [==============================] - 1s 6ms/step - loss: 2.3758e-04 - val_loss: 6.9301e-04
# Epoch 12/100
# 262/262 [==============================] - 2s 6ms/step - loss: 2.0242e-04 - val_loss: 3.5164e-04
# Epoch 13/100
# 262/262 [==============================] - 1s 6ms/step - loss: 2.0899e-04 - val_loss: 9.4598e-04
# Epoch 14/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.7503e-04 - val_loss: 3.1015e-04
# Epoch 15/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.6867e-04 - val_loss: 2.8844e-04
# Epoch 16/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.6541e-04 - val_loss: 2.9748e-04
# Epoch 17/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.4070e-04 - val_loss: 2.6978e-04
# Epoch 18/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.4810e-04 - val_loss: 2.4833e-04
# Epoch 19/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.3647e-04 - val_loss: 2.3943e-04
# Epoch 20/100
# 262/262 [==============================] - 2s 6ms/step - loss: 1.2279e-04 - val_loss: 2.0294e-04
# Epoch 21/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.2084e-04 - val_loss: 2.7199e-04
# Epoch 22/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.0521e-04 - val_loss: 2.0756e-04
# Epoch 23/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.0325e-04 - val_loss: 1.7889e-04
# Epoch 24/100
# 262/262 [==============================] - 1s 5ms/step - loss: 9.8374e-05 - val_loss: 3.2163e-04
# Epoch 25/100
# 262/262 [==============================] - 1s 5ms/step - loss: 9.3212e-05 - val_loss: 1.8539e-04
# Epoch 26/100
# 262/262 [==============================] - 1s 5ms/step - loss: 8.7614e-05 - val_loss: 1.4469e-04
# Epoch 27/100
# 262/262 [==============================] - 1s 5ms/step - loss: 9.5749e-05 - val_loss: 1.5734e-04
# Epoch 28/100
# 262/262 [==============================] - 1s 6ms/step - loss: 8.4551e-05 - val_loss: 1.4814e-04
# Epoch 29/100
# 262/262 [==============================] - 1s 5ms/step - loss: 7.7722e-05 - val_loss: 1.7503e-04
# Epoch 30/100
# 262/262 [==============================] - 1s 6ms/step - loss: 7.3217e-05 - val_loss: 1.9736e-04
# Epoch 31/100
# 262/262 [==============================] - 1s 5ms/step - loss: 7.8583e-05 - val_loss: 1.1708e-04
# Epoch 32/100
# 262/262 [==============================] - 1s 5ms/step - loss: 6.5146e-05 - val_loss: 1.1717e-04
# Epoch 33/100
# 262/262 [==============================] - 1s 6ms/step - loss: 7.3281e-05 - val_loss: 1.2017e-04
# Epoch 34/100
# 262/262 [==============================] - 1s 6ms/step - loss: 6.9888e-05 - val_loss: 1.2700e-04
# Epoch 35/100
# 262/262 [==============================] - 2s 6ms/step - loss: 6.9425e-05 - val_loss: 1.0714e-04
# Epoch 36/100
# 262/262 [==============================] - 1s 5ms/step - loss: 6.1020e-05 - val_loss: 5.1313e-04
# Epoch 37/100
# 262/262 [==============================] - 1s 5ms/step - loss: 7.0759e-05 - val_loss: 1.9002e-04
# Epoch 38/100
# 262/262 [==============================] - 1s 6ms/step - loss: 6.1970e-05 - val_loss: 1.2294e-04
# Epoch 39/100
# 262/262 [==============================] - 1s 6ms/step - loss: 6.1529e-05 - val_loss: 1.0984e-04
# Epoch 40/100
# 262/262 [==============================] - 1s 5ms/step - loss: 6.5195e-05 - val_loss: 1.5969e-04
# Epoch 41/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.9398e-05 - val_loss: 1.0551e-04
# Epoch 42/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.7690e-05 - val_loss: 1.6453e-04
# Epoch 43/100
# 262/262 [==============================] - 1s 5ms/step - loss: 6.2547e-05 - val_loss: 1.0628e-04
# Epoch 44/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.9149e-05 - val_loss: 2.3677e-04
# Epoch 45/100
# 262/262 [==============================] - 1s 5ms/step - loss: 6.6262e-05 - val_loss: 1.6105e-04
# Epoch 46/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.7480e-05 - val_loss: 1.0799e-04
# Epoch 47/100
# 262/262 [==============================] - 1s 6ms/step - loss: 6.4978e-05 - val_loss: 1.0570e-04
# Epoch 48/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.7716e-05 - val_loss: 1.1880e-04
# Epoch 49/100
# 262/262 [==============================] - 1s 6ms/step - loss: 6.1633e-05 - val_loss: 1.0534e-04
# Epoch 50/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.7309e-05 - val_loss: 1.1050e-04
# Epoch 51/100
# 262/262 [==============================] - 2s 6ms/step - loss: 5.8851e-05 - val_loss: 1.1253e-04
# Epoch 52/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.8613e-05 - val_loss: 1.0775e-04
# Epoch 53/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.4538e-05 - val_loss: 1.5149e-04
# Epoch 54/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.8408e-05 - val_loss: 1.1181e-04
# Epoch 55/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.8903e-05 - val_loss: 1.8726e-04
# Epoch 56/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.6397e-05 - val_loss: 1.1827e-04
# Epoch 57/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.7037e-05 - val_loss: 1.1943e-04
# Epoch 58/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.8578e-05 - val_loss: 1.5724e-04
# Epoch 59/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.8697e-05 - val_loss: 1.4065e-04
# Epoch 60/100
# 262/262 [==============================] - 1s 6ms/step - loss: 6.2513e-05 - val_loss: 1.9747e-04
# Epoch 61/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.6978e-05 - val_loss: 1.1046e-04
# Epoch 62/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.7471e-05 - val_loss: 1.0581e-04
# Epoch 63/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.5956e-05 - val_loss: 1.2406e-04
# Epoch 64/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.5791e-05 - val_loss: 1.1070e-04
# Epoch 65/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.4737e-05 - val_loss: 1.2375e-04
# Epoch 66/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.6927e-05 - val_loss: 1.7289e-04
# Epoch 67/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.6379e-05 - val_loss: 1.6874e-04
# Epoch 68/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.8317e-05 - val_loss: 1.1523e-04
# Epoch 69/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.7112e-05 - val_loss: 1.0667e-04
# Epoch 70/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.7425e-05 - val_loss: 3.2319e-04
# Epoch 71/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.9962e-05 - val_loss: 1.0474e-04
# Epoch 72/100
# 262/262 [==============================] - 2s 6ms/step - loss: 5.5400e-05 - val_loss: 1.0927e-04
# Epoch 73/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.6117e-05 - val_loss: 1.0494e-04
# Epoch 74/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.5265e-05 - val_loss: 1.1644e-04
# Epoch 75/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.7412e-05 - val_loss: 1.3333e-04
# Epoch 76/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.7325e-05 - val_loss: 1.2781e-04
# Epoch 77/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.5876e-05 - val_loss: 1.1143e-04
# Epoch 78/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.5520e-05 - val_loss: 1.0820e-04
# Epoch 79/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.3608e-05 - val_loss: 1.0629e-04
# Epoch 80/100
# 262/262 [==============================] - 2s 6ms/step - loss: 5.8215e-05 - val_loss: 1.0574e-04
# Epoch 81/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.5874e-05 - val_loss: 1.2222e-04
# Epoch 82/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.3484e-05 - val_loss: 1.2309e-04
# Epoch 83/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.8067e-05 - val_loss: 1.0619e-04
# Epoch 84/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.5191e-05 - val_loss: 1.1044e-04
# Epoch 85/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.7755e-05 - val_loss: 1.3744e-04
# Epoch 86/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.7778e-05 - val_loss: 1.2188e-04
# Epoch 87/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.5238e-05 - val_loss: 1.1126e-04
# Epoch 88/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.6449e-05 - val_loss: 1.0602e-04
# Epoch 89/100
# 262/262 [==============================] - 2s 6ms/step - loss: 5.7612e-05 - val_loss: 1.8460e-04
# Epoch 90/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.6986e-05 - val_loss: 1.0490e-04
# Epoch 91/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.6043e-05 - val_loss: 1.0733e-04
# Epoch 92/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.3892e-05 - val_loss: 1.1701e-04
# Epoch 93/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.4674e-05 - val_loss: 1.2639e-04
# Epoch 94/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.4353e-05 - val_loss: 1.2205e-04
# Epoch 95/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.5188e-05 - val_loss: 1.5903e-04
# Epoch 96/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.8620e-05 - val_loss: 1.2542e-04
# Epoch 97/100
# 262/262 [==============================] - 1s 5ms/step - loss: 5.9062e-05 - val_loss: 1.1225e-04
# Epoch 98/100
# 262/262 [==============================] - 2s 6ms/step - loss: 6.0629e-05 - val_loss: 1.0905e-04
# Epoch 99/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.3637e-05 - val_loss: 1.0787e-04
# Epoch 100/100
# 262/262 [==============================] - 1s 6ms/step - loss: 5.3236e-05 - val_loss: 1.4732e-04

# %%
# Make predictions
y_pred = model.predict(X_test)

y_test = y_test.reshape((y_test.shape[0], y_test.shape[1]))
y_pred = scaler.inverse_transform(y_pred)
y_test = scaler.inverse_transform(y_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
msle = mean_squared_log_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Assuming y_pred and y_test are NumPy arrays
# Note: For MAPE, make sure y_test does not contain zeros to avoid division by zero.

# RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# MAPE
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100


print('RMSE:', rmse)
print('MAPE:', mape)


print('MSE: ', mse)
print('MSLE: ', msle)
print('MAE: ', mae)
print('R-squared: ', r2)

# Plot the predictions vs the real data
plt.plot(y_test, color='blue', label='Actual Price')
plt.plot(y_pred, color='red', label='Predicted Price')
plt.title('IBM Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('IBM Stock Price')
plt.legend()
plt.show()
# Out:
# 66/66 [==============================] - 1s 1ms/step
# RMSE: 2.385182952795883
# MAPE: 1.3390734245546518
# MSE:  5.689097718308087
# MSLE:  0.0003152315742357335
# MAE:  1.8431448779729631
# R-squared:  0.981771980849319

# %%
# predict as last day's price (this may be the case)
y_test_simple = y_test[:-1]
y_pred_simple = y_test[1:]
# Evaluate the model
mse = mean_squared_error(y_test_simple, y_pred_simple)
msle = mean_squared_log_error(y_test_simple, y_pred_simple)
mae = mean_absolute_error(y_test_simple, y_pred_simple)
r2 = r2_score(y_test_simple, y_pred_simple)

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Assuming y_pred and y_test are NumPy arrays
# Note: For MAPE, make sure y_test does not contain zeros to avoid division by zero.

# RMSE
rmse = np.sqrt(mean_squared_error(y_test_simple, y_pred_simple))

# MAPE
mape = np.mean(np.abs((y_test_simple - y_pred_simple) / y_test_simple)) * 100


print('RMSE:', rmse)
print('MAPE:', mape)


print('MSE: ', mse)
print('MSLE: ', msle)
print('MAE: ', mae)
print('R-squared: ', r2)

# plot the results
plt.figure(figsize=(14, 5))
plt.plot(y_test, color='blue', label='Actual')
plt.plot(y_pred, color='red', label='Predicted')
plt.title('IBM stock price prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# RMSE: 2.01215177259292
# MAPE: 1.010759504367407
# MSE:  4.04875475594883
# MSLE:  0.00023393102175387696
# MAE:  1.3679685345158203
# R-squared:  0.9870311432403817

# %%
# calculate pearson correlation between pred and pred_simple
from scipy.stats import pearsonr
corr, _ = pearsonr(y_pred[:-1].squeeze(), y_pred_simple.squeeze())
print('Pearsons correlation: %.3f' % corr)

# plot the results
plt.figure(figsize=(14, 5))
plt.plot(y_pred[:-1], color='blue', label='Predicted')
plt.plot(y_pred_simple, color='red', label='Predicted_simple')
plt.title('IBM stock price prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Pearsons correlation: 0.987

# %% [markdown]
# # 1
# RMSE: 3.4254854508410113
# MAPE: 1.8144602678363666
# MSE:  11.733950573923448
# MSLE:  0.0006569501219651215
# MAE:  2.4491094395626716
# R-squared:  0.9631499914253284
#
# # 1-3
#
# RMSE: 6.078880969983048
# MAPE: 3.316567922817762
# MSE:  36.95279384722205
# MSLE:  0.002067308836169198
# MAE:  4.445746821684231
# R-squared:  0.8816022738103634
#
# # 1-3-9
#
# RMSE: 9.681496370442565
# MAPE: 5.433762503375542
# MSE:  93.73137197089255
# MSLE:  0.005184730334292754
# MAE:  7.309876317143523
# R-squared:  0.6795390158852281
