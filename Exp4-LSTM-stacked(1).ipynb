# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import tensorflow as tf
import random
# set experiment consistency
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# turn gpu on
physical_devices = tf.config.list_physical_devices('GPU')
# Load data from the text file
with open('./data/IBM.txt', 'r') as file:
    lines = file.readlines()
    data = []
    dates = []

    for line in lines[1:]:
        parts = line.strip().split(',')
        date = parts[0]
        if '1980-12-12' <= date <= '2022-07-22':
            dates.append(date)
            data.append(float(parts[4]))  # 'Close' column

# Create a DataFrame from the loaded data
df = pd.DataFrame({'Date': pd.to_datetime(dates), 'Value': data})

# Set the 'Date' column as the index
df.set_index('Date', inplace=True)

# Extract the values from the DataFrame
signal = df['Value'].values
signal = signal.reshape(-1, 1)

# Define the training and testing data
train_size = int(len(signal) * 0.8)
train_data = signal[:train_size, :]
test_data = signal[train_size:, :]

# normalization
scaler = MinMaxScaler()
scaler.fit(train_data)
train_data = scaler.transform(train_data)
test_data = scaler.transform(test_data)

def create_groups(dataset, window_size_3, timeslice, step):
    X_data, y_data = [], []
    index = 0
    while index + (timeslice * window_size_3) < len(dataset):
        i = 0
        t3 = []

        # Populate t3
        while i < timeslice * window_size_3:
            current_slice = dataset[index + i:index + i + window_size_3, 0]
            if not np.isnan(current_slice).all():
                t3.append(np.mean(current_slice))
            i += window_size_3


        t3=np.flip(t3)
        X_data.append(np.concatenate([t3]))
        y_data.append(dataset[index + timeslice * window_size_3])
        index += step

    return np.array(X_data), np.array(y_data)

window_size_1 = 1
window_size_2 = 3
window_size_3 = 9
timeslice = 12
step = 1
X_train, y_train = create_groups(train_data, window_size_1, timeslice, step)
X_test, y_test = create_groups(test_data, window_size_1, timeslice, step)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
y_train[0]
# Out:
# array([0.03268669])

# %%
# Define the LSTM model architecture
model = Sequential()
model.add(LSTM(units=16, return_sequences=True, input_shape=(X_train.shape[1], 1)))
# model.add(Dropout(0.2))
model.add(LSTM(units=32, return_sequences=True))
# model.add(Dropout(0.2))
model.add(LSTM(units=16, return_sequences=False))
# model.add(Dropout(0.2))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Plot the training loss and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 262/262 [==============================] - 4s 7ms/step - loss: 0.0063 - val_loss: 6.1457e-04
# Epoch 2/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.8167e-04 - val_loss: 6.2725e-04
# Epoch 3/100
# 262/262 [==============================] - 2s 6ms/step - loss: 1.8215e-04 - val_loss: 3.4582e-04
# Epoch 4/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.8092e-04 - val_loss: 4.2641e-04
# Epoch 5/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.9054e-04 - val_loss: 3.7740e-04
# Epoch 6/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.9013e-04 - val_loss: 3.2584e-04
# Epoch 7/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.7506e-04 - val_loss: 3.6113e-04
# Epoch 8/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.8660e-04 - val_loss: 5.1214e-04
# Epoch 9/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.8167e-04 - val_loss: 4.5358e-04
# Epoch 10/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.6106e-04 - val_loss: 7.3892e-04
# Epoch 11/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.8434e-04 - val_loss: 2.9899e-04
# Epoch 12/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.6418e-04 - val_loss: 5.4228e-04
# Epoch 13/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.6103e-04 - val_loss: 2.8543e-04
# Epoch 14/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.5572e-04 - val_loss: 2.9354e-04
# Epoch 15/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.5515e-04 - val_loss: 2.8491e-04
# Epoch 16/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.9102e-04 - val_loss: 3.0952e-04
# Epoch 17/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.4247e-04 - val_loss: 3.2923e-04
# Epoch 18/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.6103e-04 - val_loss: 9.3946e-04
# Epoch 19/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.5610e-04 - val_loss: 3.0331e-04
# Epoch 20/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.3215e-04 - val_loss: 3.1884e-04
# Epoch 21/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.5418e-04 - val_loss: 2.5110e-04
# Epoch 22/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.2829e-04 - val_loss: 2.2404e-04
# Epoch 23/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.3658e-04 - val_loss: 2.2725e-04
# Epoch 24/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.3471e-04 - val_loss: 2.7744e-04
# Epoch 25/100
# 262/262 [==============================] - 2s 7ms/step - loss: 1.3048e-04 - val_loss: 2.4449e-04
# Epoch 26/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1487e-04 - val_loss: 2.4996e-04
# Epoch 27/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.4374e-04 - val_loss: 5.1484e-04
# Epoch 28/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.4894e-04 - val_loss: 2.0730e-04
# Epoch 29/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1434e-04 - val_loss: 2.3541e-04
# Epoch 30/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1929e-04 - val_loss: 2.2426e-04
# Epoch 31/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1853e-04 - val_loss: 1.9937e-04
# Epoch 32/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.1908e-04 - val_loss: 1.9901e-04
# Epoch 33/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.2369e-04 - val_loss: 1.9496e-04
# Epoch 34/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1705e-04 - val_loss: 2.1136e-04
# Epoch 35/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1232e-04 - val_loss: 1.8005e-04
# Epoch 36/100
# 262/262 [==============================] - 2s 6ms/step - loss: 1.0955e-04 - val_loss: 5.8332e-04
# Epoch 37/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.1620e-04 - val_loss: 1.8935e-04
# Epoch 38/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.2249e-04 - val_loss: 2.5989e-04
# Epoch 39/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1242e-04 - val_loss: 1.9244e-04
# Epoch 40/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1256e-04 - val_loss: 4.3862e-04
# Epoch 41/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1666e-04 - val_loss: 2.1185e-04
# Epoch 42/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.0154e-04 - val_loss: 2.6407e-04
# Epoch 43/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1144e-04 - val_loss: 2.1004e-04
# Epoch 44/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.0007e-04 - val_loss: 4.1974e-04
# Epoch 45/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.0466e-04 - val_loss: 4.1121e-04
# Epoch 46/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.0981e-04 - val_loss: 3.6229e-04
# Epoch 47/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.1318e-04 - val_loss: 1.7499e-04
# Epoch 48/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.0395e-04 - val_loss: 1.7132e-04
# Epoch 49/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.0408e-04 - val_loss: 1.6960e-04
# Epoch 50/100
# 262/262 [==============================] - 2s 6ms/step - loss: 9.6451e-05 - val_loss: 2.4026e-04
# Epoch 51/100
# 262/262 [==============================] - 2s 6ms/step - loss: 1.1923e-04 - val_loss: 2.2124e-04
# Epoch 52/100
# 262/262 [==============================] - 1s 5ms/step - loss: 9.4040e-05 - val_loss: 1.7966e-04
# Epoch 53/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.0402e-04 - val_loss: 2.1312e-04
# Epoch 54/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.0891e-04 - val_loss: 1.7774e-04
# Epoch 55/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.0187e-04 - val_loss: 4.8949e-04
# Epoch 56/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.0162e-04 - val_loss: 1.6247e-04
# Epoch 57/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1554e-04 - val_loss: 2.2972e-04
# Epoch 58/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.0428e-04 - val_loss: 1.8830e-04
# Epoch 59/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.0313e-04 - val_loss: 1.7475e-04
# Epoch 60/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.0725e-04 - val_loss: 4.1280e-04
# Epoch 61/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.0038e-04 - val_loss: 2.1542e-04
# Epoch 62/100
# 262/262 [==============================] - 1s 5ms/step - loss: 9.3879e-05 - val_loss: 2.0653e-04
# Epoch 63/100
# 262/262 [==============================] - 1s 5ms/step - loss: 9.7735e-05 - val_loss: 2.5890e-04
# Epoch 64/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1436e-04 - val_loss: 1.6214e-04
# Epoch 65/100
# 262/262 [==============================] - 1s 6ms/step - loss: 9.6377e-05 - val_loss: 1.5927e-04
# Epoch 66/100
# 262/262 [==============================] - 2s 6ms/step - loss: 9.7827e-05 - val_loss: 1.6809e-04
# Epoch 67/100
# 262/262 [==============================] - 1s 6ms/step - loss: 1.0241e-04 - val_loss: 1.7243e-04
# Epoch 68/100
# 262/262 [==============================] - 1s 6ms/step - loss: 9.8526e-05 - val_loss: 1.5525e-04
# Epoch 69/100
# 262/262 [==============================] - 1s 5ms/step - loss: 9.0567e-05 - val_loss: 2.0591e-04
# Epoch 70/100
# 262/262 [==============================] - 1s 6ms/step - loss: 9.0571e-05 - val_loss: 5.5116e-04
# Epoch 71/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.0112e-04 - val_loss: 1.7523e-04
# Epoch 72/100
# 262/262 [==============================] - 1s 6ms/step - loss: 9.3952e-05 - val_loss: 2.1014e-04
# Epoch 73/100
# 262/262 [==============================] - 2s 6ms/step - loss: 1.0239e-04 - val_loss: 3.3651e-04
# Epoch 74/100
# 262/262 [==============================] - 2s 6ms/step - loss: 1.0022e-04 - val_loss: 2.2267e-04
# Epoch 75/100
# 262/262 [==============================] - 1s 5ms/step - loss: 8.9523e-05 - val_loss: 2.3271e-04
# Epoch 76/100
# 262/262 [==============================] - 1s 5ms/step - loss: 9.4577e-05 - val_loss: 1.6179e-04
# Epoch 77/100
# 262/262 [==============================] - 1s 5ms/step - loss: 9.1123e-05 - val_loss: 1.6029e-04
# Epoch 78/100
# 262/262 [==============================] - 2s 6ms/step - loss: 8.7718e-05 - val_loss: 2.6365e-04
# Epoch 79/100
# 262/262 [==============================] - 1s 5ms/step - loss: 9.8939e-05 - val_loss: 1.7288e-04
# Epoch 80/100
# 262/262 [==============================] - 1s 5ms/step - loss: 1.1326e-04 - val_loss: 1.4723e-04
# Epoch 81/100
# 262/262 [==============================] - 1s 5ms/step - loss: 8.9598e-05 - val_loss: 1.4979e-04
# Epoch 82/100
# 262/262 [==============================] - 1s 6ms/step - loss: 8.6904e-05 - val_loss: 1.6389e-04
# Epoch 83/100
# 262/262 [==============================] - 1s 6ms/step - loss: 9.6948e-05 - val_loss: 1.4945e-04
# Epoch 84/100
# 262/262 [==============================] - 2s 6ms/step - loss: 9.8392e-05 - val_loss: 4.5680e-04
# Epoch 85/100
# 262/262 [==============================] - 2s 6ms/step - loss: 9.0614e-05 - val_loss: 1.9639e-04
# Epoch 86/100
# 262/262 [==============================] - 1s 5ms/step - loss: 9.0895e-05 - val_loss: 1.5697e-04
# Epoch 87/100
# 262/262 [==============================] - 1s 5ms/step - loss: 8.8294e-05 - val_loss: 1.4737e-04
# Epoch 88/100
# 262/262 [==============================] - 1s 5ms/step - loss: 8.4745e-05 - val_loss: 1.5388e-04
# Epoch 89/100
# 262/262 [==============================] - 1s 6ms/step - loss: 8.7769e-05 - val_loss: 1.8102e-04
# Epoch 90/100
# 262/262 [==============================] - 1s 5ms/step - loss: 9.0151e-05 - val_loss: 1.6464e-04
# Epoch 91/100
# 262/262 [==============================] - 2s 6ms/step - loss: 8.6028e-05 - val_loss: 1.3923e-04
# Epoch 92/100
# 262/262 [==============================] - 1s 6ms/step - loss: 8.0393e-05 - val_loss: 1.6646e-04
# Epoch 93/100
# 262/262 [==============================] - 1s 5ms/step - loss: 8.6639e-05 - val_loss: 1.4091e-04
# Epoch 94/100
# 262/262 [==============================] - 1s 6ms/step - loss: 8.6236e-05 - val_loss: 1.6635e-04
# Epoch 95/100
# 262/262 [==============================] - 1s 5ms/step - loss: 8.1770e-05 - val_loss: 2.2368e-04
# Epoch 96/100
# 262/262 [==============================] - 1s 5ms/step - loss: 8.8345e-05 - val_loss: 2.3735e-04
# Epoch 97/100
# 262/262 [==============================] - 1s 5ms/step - loss: 8.7702e-05 - val_loss: 2.4566e-04
# Epoch 98/100
# 262/262 [==============================] - 2s 6ms/step - loss: 1.0028e-04 - val_loss: 1.8716e-04
# Epoch 99/100
# 262/262 [==============================] - 1s 6ms/step - loss: 8.0654e-05 - val_loss: 1.4079e-04
# Epoch 100/100
# 262/262 [==============================] - 1s 5ms/step - loss: 8.2853e-05 - val_loss: 1.3805e-04

# %%
# Make predictions
y_pred = model.predict(X_test)

y_test = y_test.reshape((y_test.shape[0], y_test.shape[1]))
y_pred = scaler.inverse_transform(y_pred)
y_test = scaler.inverse_transform(y_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
msle = mean_squared_log_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Assuming y_pred and y_test are NumPy arrays
# Note: For MAPE, make sure y_test does not contain zeros to avoid division by zero.

# RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

# MAPE
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100


print('RMSE:', rmse)
print('MAPE:', mape)


print('MSE: ', mse)
print('MSLE: ', msle)
print('MAE: ', mae)
print('R-squared: ', r2)

# Plot the predictions vs the real data
plt.plot(y_test, color='blue', label='Actual Price')
plt.plot(y_pred, color='red', label='Predicted Price')
plt.title('IBM Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('IBM Stock Price')
plt.legend()
plt.show()
# Out:
# 66/66 [==============================] - 1s 1ms/step
# RMSE: 2.3088999344808543
# MAPE: 1.195674701226585
# MSE:  5.331018907445694
# MSLE:  0.0003037846268735374
# MAE:  1.6166544642225762
# R-squared:  0.9829192748043601

# %%
# predict as last day's price (this may be the case)
y_test_simple = y_test[:-1]
y_pred_simple = y_test[1:]
# Evaluate the model
mse = mean_squared_error(y_test_simple, y_pred_simple)
msle = mean_squared_log_error(y_test_simple, y_pred_simple)
mae = mean_absolute_error(y_test_simple, y_pred_simple)
r2 = r2_score(y_test_simple, y_pred_simple)

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Assuming y_pred and y_test are NumPy arrays
# Note: For MAPE, make sure y_test does not contain zeros to avoid division by zero.

# RMSE
rmse = np.sqrt(mean_squared_error(y_test_simple, y_pred_simple))

# MAPE
mape = np.mean(np.abs((y_test_simple - y_pred_simple) / y_test_simple)) * 100


print('RMSE:', rmse)
print('MAPE:', mape)


print('MSE: ', mse)
print('MSLE: ', msle)
print('MAE: ', mae)
print('R-squared: ', r2)

# plot the results
plt.figure(figsize=(14, 5))
plt.plot(y_test, color='blue', label='Actual')
plt.plot(y_pred, color='red', label='Predicted')
plt.title('IBM stock price prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# RMSE: 2.01215177259292
# MAPE: 1.010759504367407
# MSE:  4.04875475594883
# MSLE:  0.00023393102175387696
# MAE:  1.3679685345158203
# R-squared:  0.9870311432403817

# %%
# calculate pearson correlation between pred and pred_simple
from scipy.stats import pearsonr
corr, _ = pearsonr(y_pred[:-1].squeeze(), y_pred_simple.squeeze())
print('Pearsons correlation: %.3f' % corr)

# plot the results
plt.figure(figsize=(14, 5))
plt.plot(y_pred[:-1], color='blue', label='Predicted')
plt.plot(y_pred_simple, color='red', label='Predicted_simple')
plt.title('IBM stock price prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Pearsons correlation: 0.985

# %% [markdown]
# # 1
# RMSE: 3.4254854508410113
# MAPE: 1.8144602678363666
# MSE:  11.733950573923448
# MSLE:  0.0006569501219651215
# MAE:  2.4491094395626716
# R-squared:  0.9631499914253284
#
# # 1-3
#
# RMSE: 6.078880969983048
# MAPE: 3.316567922817762
# MSE:  36.95279384722205
# MSLE:  0.002067308836169198
# MAE:  4.445746821684231
# R-squared:  0.8816022738103634
#
# # 1-3-9
#
# RMSE: 9.681496370442565
# MAPE: 5.433762503375542
# MSE:  93.73137197089255
# MSLE:  0.005184730334292754
# MAE:  7.309876317143523
# R-squared:  0.6795390158852281
